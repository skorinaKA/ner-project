# %%
from span_marker import SpanMarkerModel

# %% [markdown]
# Подготовка модели

# %%
model = SpanMarkerModel.from_pretrained("../models/tomaarsen/span-marker-bert-base-cased-fewnerd-fine-super/checkpoint-final")
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %% [markdown]
# Проверка модели

# %%
entities = model.predict("Amelia Earhart flew her single engine Lockheed Vega 5B across the Atlantic to Paris.")
entities
# Out:
# SpanMarker model predictions are being computed on the CPU while CUDA is available. Moving the model to CUDA using `model.cuda()` before performing predictions is heavily recommended to significantly boost prediction speeds.
# [{'span': 'Amelia Earhart',
#   'label': 'person-other',
#   'score': 0.787898600101471,
#   'char_start_index': 0,
#   'char_end_index': 14},
#  {'span': 'Lockheed Vega 5B',
#   'label': 'product-airplane',
#   'score': 0.9290245771408081,
#   'char_start_index': 38,
#   'char_end_index': 54},
#  {'span': 'Atlantic',
#   'label': 'location-bodiesofwater',
#   'score': 0.8763556480407715,
#   'char_start_index': 66,
#   'char_end_index': 74},
#  {'span': 'Paris',
#   'label': 'location-GPE',
#   'score': 0.9797185659408569,
#   'char_start_index': 78,
#   'char_end_index': 83}]
